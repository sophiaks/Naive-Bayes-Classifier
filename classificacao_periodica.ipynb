# %%
from time import sleep
import pandas as pd

for e in range(3):
    # !jupyter nbconvert --to notebook --execute Projeto2_layout.ipynb
    dashboard = pd.read_excel("fill_auto.xlsx")
    #print(f"dashoard: {dashoard}")
    sleep(5)
    print(dashboard)
# Out:
# [NbConvertApp] Converting notebook Projeto2_layout.ipynb to notebook
# [NbConvertApp] Executing notebook with kernel: python3
# [NbConvertApp] ERROR | Timeout waiting for execute reply (30s).
# Traceback (most recent call last):
#   File "C:\Users\User\Anaconda3\lib\site-packages\nbconvert\preprocessors\execute.py", line 423, in _wait_for_reply
#     msg = self.kc.shell_channel.get_msg(timeout=timeout)
#   File "C:\Users\User\Anaconda3\lib\site-packages\jupyter_client\blocking\channels.py", line 57, in get_msg
#     raise Empty
# _queue.Empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\Anaconda3\Scripts\jupyter-nbconvert-script.py", line 10, in <module>
#     sys.exit(main())
#   File "C:\Users\User\Anaconda3\lib\site-packages\jupyter_core\application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
# ...

# %%
dashboard.head()
# Out:
#                                                Teste Clas_manual Categorias
# 0  a coisa mais idiota de 13 reasons why foi colo...           N          N
# 1  atribuí nota 8 ao episódio 3x1 - yeah. i'm the...           O          N
# 2  rt @citou13reasons: ''quando você julga uma pe...           O          N
# 3  terminei 13 reasons why também, meu hobbie é c...           R          N
# 4  rt @wivisampaio: saiu a nova temporada de elit...           O          N

# %%
5
# Out:
# 5
