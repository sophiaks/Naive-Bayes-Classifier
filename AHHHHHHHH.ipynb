# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# Nome: Amanda Rosa do Carmo
#
# Nome: Beatriz Cabral
#
# Nome: Sophia Kerber Shigueoka

# %% [markdown]
# Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# # Classificador automático de sentimento

# %% [markdown]
# ## 1. Introdução

# %% [markdown]
# O objetivo desse projeto é criar um classificador capaz de analisar como a audiência de “13 reasons why”, uma série de televisão polêmica, está reagindo. Para tal fim, será feita uma análise da probabilidade de um tweet ser relevante dada as palavras do seu conteúdo, utilizando o princípio do algoritimo de Naive Bayes.

# %% [markdown]
# ## 2. Desenvolvimento e metodologia

# %% [markdown]
#    A fim de simplificar a explicação do processo de desenvolvimento do projeto, ele será dividido em  X etapas.

# %% [markdown]
# ### ETAPA 1 - Preparando o ambiente no jupyter

# %% [markdown]
# Nessa etapa, serão baixadas e importadas todas as bibliotecas relevantes para o código, bem como implementadas todas as funções a serem utilizadas

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
#Importando as bibliotecas
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %%
import re 

def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    punctuation = '[!\-.:?;•,]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', text)
    return text_subbed

# %% [markdown]
# ___
# ### ETAPA 2 - Autenticando no  Twitter
#
# * Conta: ***@KerberSophie***

# %% [markdown]
# Aqui será feita a autenticação no twitter, a partir de um código obtido no próprio site.

# %%
#Dados de autenticação do twitter:

#Coloque aqui o identificador da conta no twitter: @KerberSophie

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
# auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ### ETAPA 3 - Escolha de um produto e coleta das mensagens

# %% [markdown]
# Primeiramente, iremos fazer a coleta dos dados, nesse caso de tweets, a partir da keyword “13 reasons why” escolhida. Feita a coleta, os dados foram salvos dentro de uma planilha no excel. Para importar as mensagens do Twitter, foi necessário o uso da biblioteca Tweepy.

# %% [markdown]
# Quantidade mínima de mensagens capturadas:
# Escolhemos 1480 a partir de um método empírico. Quando testamos com 1000 não conseguimos tweets suficientes, e chegamos
# a conclusão de que o problema era proveniente do set(), que diminuía a quantidade de tweets baixados. Assim, decidiu-se
# aumentar a quantidade de tweets para 1500, já que com 1000 ficaram falatando 360 tweets. Com 1500, ficamos com 20 tweets a mais.
# como eram somente 20 tweets, imaginamos que poucos deles seriam retweets, então tiramos exatamente 20 tweets dos 1500.
# Com 1480 tweets, conseguimos 399 tweets de teste, ou seja, faltou somente 1. não achamos que 1 tweets afetará tanto a base
# de dados, então decidimos manter os 1480.

# %%
#Produto escolhido:
produto = '13 Reasons Why'

n = 1480
#Quantidade mínima de mensagens para a base de treinamento:
t = 600

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %%
# #Cria um objeto para a captura
# api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# #Inicia a captura, para mais detalhes: ver a documentação do tweepy
# i = 1
# msgs = []
# for msg in tweepy.Cursor(api.search, q=produto, lang=lang).items():    
#     msgs.append(msg.text.lower())
#     i += 1
#     if i > n:
#         break

# #Embaralhando as mensagens para reduzir um possível viés
# list = []
# shuffle(msgs)

# #Usando o set() para tirar os retweets
# listaset = set(msgs)

# #Adicionando o resultado do set() a uma lista para evitar o erro TypeError: 'set' object is not subscriptable
# for value in listaset:
#     list.append(value)

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
# #Linhas abaixo foram comentadas uma vez que o conjunto de dados era o mesmo, mas o número de tweets foi alterado.

# # #Verifica se o arquivo não existe para não substituir um conjunto pronto
# # if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
#     #Abre o arquivo para escrita
# writer = pd.ExcelWriter('{0} novo.xlsx'.format(produto))

#     #divide o conjunto de mensagens em duas planilhas
# dft = pd.DataFrame({'Treinamento' : pd.Series(list[:t])})
# dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

# dfc = pd.DataFrame({'Teste' : pd.Series(list[t:])})
# dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

#     #fecha o arquivo
# writer.save()

# %% [markdown]
# ### ETAPA 4 - Classificação manual dos tweets

# %% [markdown]
# Previamente, foram estabelecidas 4 categorias para a classificação das mensagens, entre elas,
#
# * 	***P*** - Positivo – se a mensagem transmitida for positiva;
# *	***N*** - Negativo – se a mensagem transmitida for negativa;
# *	***O*** - Irrelevante – se a mensagem transmitida não for relevante para análise e/ou não se encaixar em nenhuma das outras categorias;
# *	***R*** - Reação – se a mensagem transmitida for uma reação sobre algum episódio, temporada, ou da série em geral.
#
# Estabelecidas as categorias e selecionados os tweets, será criada uma base de treinamento, na qual as mensagens serão qualificadas manualmente no excel de acordo com as categoria mais propícias.

# %% [markdown]
# ___
# ### ETAPA 5 - Montando o Classificador Naive-Bayes

# %% [markdown]
# ### Naive Bayes
# O algoritmo de Naive Bayes é um classificador probabilístico baseado no teorema de Bayes, utilizado no processo de machine learning. O algoritmo supõe que uma característica independe da outra para acontecer, ou seja, mesmo na presença de uma característica particular em uma classe, isso não afeta na probabilidade de qualquer característica ocorrer. O teorema de bayes é escrito da seguinte forma:
#
# *** colocar a formula de bayes ***

# %% [markdown]
# Esse método será utilizado no projeto, uma vez que permite calcular a probabilidade de uma mensagem ser positiva, por exemplo, dada as palavras utilizadas, assumindo que as palavras em um tweet não tem nenhuma relação entre elas.
#
# A partir do nosso modelo, poderíamos reescrever o teorema de bayes da seguinte forma:
#
# *** colocar a formula de bayes nosso modelo ***
#
# A variável C é a classe variável que representa se um tweet será positivo, negativo, irrelevante ou uma reação, a partir das condições estabelecidas (probabilidade de ocorrência de uma palavra dada as condições). A variável P representa as palavras ocorridas nos tweets. P pode ser:
#
# *** colocar os possiveis valores de P ***
#
# Substituindo P por cada uma das possíveis palavras, temos:
#
# *** colocar a formula de bayes nosso modelo  com valores de P***

# %% [markdown]
# Para implementar esse algoritmo, uma nova tabela deve ser criada com as palavras e suas respectivas frequências relativas em cada uma das categorias. Porém antes disso, deverá ser feita uma limpeza das mensagens, removendo pontuações e caracteres que não convém a análise.

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %%
import re 

def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    punctuation = '[!\-.:?;•,]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', text)
    return text_subbed

# %%
excel = pd.read_excel('13 Reasons Why v2.xlsx', sheet_name='Treinamento')
excel.head()
# Out:
#                                          Treinamento Categoria
# 0  alguém aq ja assistiu a 3° temp de 13 reasons ...         O
# 1  (na 3° temporada de 13 reasons why) eu estou t...         R
# 2  13 ep de 13 reasons why p tentar fazer vc sent...         N
# 3  nossa nem sabia que tinha lançado a 3° tempora...         O
# 4  estava começando a ver  o primeiro episódio de...         N

# %%
excel_treino = pd.read_excel('13 Reasons Why v2.xlsx', sheet_name='Teste')
excel_treino.rename(columns={'Unnamed: 1':'Clas_manual'}, inplace=True) 
excel_treino.head()
# Out:
#                                                Teste Clas_manual
# 0  a coisa mais idiota de 13 reasons why foi colo...           N
# 1  atribuí nota 8 ao episódio 3x1 - yeah. i'm the...           O
# 2  rt @citou13reasons: ''quando você julga uma pe...           O
# 3  terminei 13 reasons why também, meu hobbie é c...           R
# 4  rt @wivisampaio: saiu a nova temporada de elit...           O

# %%
# Função para limpar e criar tabela de frequências relativas

def FreqRel(cat):
    texto_completo = ' '.join(excel[excel.Categoria==cat].Treinamento)
    semhttp = re.sub(r'http\S+', '', texto_completo)
    text_limpo = cleanup(semhttp)
    rel = text_limpo.split()
    freq_rel = pd.Series(rel).value_counts(True)
    return freq_rel

def FreqAbs(cat):
    texto_completo = ' '.join(excel[excel.Categoria==cat].Treinamento)
    semhttp = re.sub(r'http\S+', '', texto_completo)
    text_limpo = cleanup(semhttp)
    rel = text_limpo.split()
    freq_abs = pd.Series(rel).value_counts()
    return freq_abs

FreqAbs('P')
# Out:
# reasons           72
# why               68
# 13                68
# de                62
# a                 38
# temporada         29
# que               20
# o                 14
# é                 13
# eu                13
# foi               12
# e                 11
# da                10
# série             10
# essa               9
# uma                9
# tá                 9
# mas                9
# q                  9
# muito              8
# boa                8
# terceira           8
# não                8
# ao                 7
# foda               7
# nota               7
# atribuí            7
# #bancodeseries     7
# episódio           7
# to                 6
#                   ..
# única              1
# molestia           1
# agora              1
# ''13               1
# todo               1
# pelo               1
# lá                 1
# problems           1
# gosto              1
# sobrevivência      1
# discutidas         1
# fenomenal          1
# ai                 1
# tempo              1
# consegue           1
# deme               1
# sentir             1
# estou              1
# sei                1
# estava             1
# d+                 1
# opinião            1
# co…                1
# @botts___          1
# coi…               1
# jensen             1
# aff                1
# pessoas            1
# 3x7                1
# fazendo            1
# Length: 423, dtype: int64

# %%
# Estas funções dividem a função anterior
def Limpa(texto):
    semhttp = re.sub(r'http\S+', '', texto)
    text_limpo = cleanup(semhttp)
    rel = text_limpo.split()
    return(rel)

# def FreqRel(Limpa):
#     print(Limpa(texto_completo))
#     freq_rel = pd.Series(Limpa).value_counts(True)
#     return freq_rel

# %% [markdown]
# ___
# ### Descobrindo P(N), P(R), P(P) e P(0)

# %%
texto_1 = ' '.join(excel[excel.Categoria=='O'].Treinamento)
texto_2 = ' '.join(excel[excel.Categoria=='R'].Treinamento)
texto_3 = ' '.join(excel[excel.Categoria=='P'].Treinamento)
texto_4 = ' '.join(excel[excel.Categoria=='N'].Treinamento)

texto_1 = Limpa(texto_1)
texto_2 = Limpa(texto_2)
texto_3 = Limpa(texto_3)
texto_4 = Limpa(texto_4)

#juntando todos os textos
texto_enorme = texto_1 + texto_2 + texto_3 + texto_4
set(texto_enorme)
dic_global = 0
for palavra in texto_enorme:
        dic_global+=1
    
print('Todas as palavras somadas:')
print(dic_global)

def prob_cat(cat):
    palavras = 0
    texto_completo = ' '.join(excel[excel.Categoria==cat].Treinamento)
    texto_completo.replace('•', '')
    semhttp = re.sub(r'http\S+', '', texto_completo)
    text_limpo = cleanup(semhttp)
    rel = text_limpo.split()
    set(rel)
    # Para verificar se o código era coerente, imprimimos o total de palavras de cada categoria
    for palavra in rel:
        palavras += 1
    prob_final = palavras/dic_global
    return prob_final
# Out:
# Todas as palavras somadas:
# 10095

# %%
print("Probabilidade da Categoria 'Neutro'")
print(prob_cat('O'))
print('')
print("Probabilidade da Categoria 'Negativo'")
print(prob_cat('N'))
print('')
print("Probabilidade da Categoria 'Positivo'")
print(prob_cat('P'))
print('')
print("Probabilidade da Categoria 'Reação'")
print(prob_cat('R'))



print('')
print("Probabilidade Total (se tudo der certo, deve ser 1)")
print(prob_cat('O') + prob_cat('N') + prob_cat('P') + prob_cat('R'))
# Out:
# Probabilidade da Categoria 'Neutro'
# 0.5090638930163447
#
# Probabilidade da Categoria 'Negativo'
# 0.2220901436354631
#
# Probabilidade da Categoria 'Positivo'
# 0.11362060425953442
#
# Probabilidade da Categoria 'Reação'
# 0.15522535908865776
#
# Probabilidade Total (se tudo der certo, deve ser 1)
# 1.0

# %%
try:
    Fqr = FreqAbs('R')
    Fqn = FreqAbs('N')
    Fqp = FreqAbs('P')
    Fqo = FreqAbs('O')
except: 
    pass

FreqAbs('O')
# Out:
# reasons          268
# 13               264
# why              255
# de               243
# a                154
# e                131
# temporada         95
# elite             78
# que               70
# eu                61
# o                 51
# não               50
# assistir          49
# rt                42
# sobre             34
# 3                 34
# pra               34
# 2                 32
# é                 31
# da                30
# do                30
# 1                 29
# ver               29
# terceira          28
# séries            27
# vou               27
# q                 26
# to                24
# com               23
# se                23
#                 ...
# bizarros           1
# importante         1
# lembrou            1
# esses              1
# adole              1
# finalizadas        1
# souberam           1
# rapidão            1
# tyler              1
# aq                 1
# ccxp               1
# viram              1
# @jvjbts7           1
# enfim              1
# feira              1
# percebeu           1
# imperfeito         1
# tomar              1
# seg…               1
# 🙄🙄                 1
# jeito              1
# feios              1
# @seriesbrasil      1
# nossa              1
# outros             1
# @nathlaino         1
# maravilhosas       1
# mano               1
# comparei           1
# apanhas            1
# Length: 1288, dtype: int64

# %%
Neutro_set = set(FreqRel(0).index)
Reacao_set = set(FreqRel('R').index)

# %% [markdown]
# ___
# ### Verificando a performance
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ###   P(N | palavras) = P(N) * P(cada_palavra | N)
#
# NÃO É PRECISO DIVIDIR PELA PROBABILIDADE

# %%
import numpy as np
pR = np.sum(Fqr)
pN = np.sum(Fqn)
pP = np.sum(Fqp)
pO = np.sum(Fqo)

alpha = 1
V = 1e6

# %%
pR
# Out:
# 1567

# %%
# Isso tá certo, talkey?

prob_R = 1
prob_tweet = 1
dicR = {}
for tweet in excel_treino['Teste']:
    tweet = cleanup(tweet)
    pal_tweet = tweet.split()
    probabilidade = 1
    for palavra_teste in pal_tweet:
        # Calcula prob da palavra com smoothing.
        c = 0
        if palavra_teste in Fqr:
            c = Fqr[palavra_teste]
        p = (c + alpha)/(pR + alpha*V)
        prob_tweet = prob_tweet * p
        
    prob_final = prob_tweet * prob_cat('R')
    dicR[tweet] = prob_final

# %%
prob_N = 1
prob_tweet = 1
dicN = {}
for tweet in excel_treino['Teste']:
    tweet = cleanup(tweet)
    pal_tweet = tweet.split()
    probabilidade = 1
    for palavra_teste in pal_tweet:
        c = 0
        if palavra_teste in Fqn:
            c = Fqn[palavra_teste]
        p = (c + alpha)/(pN + alpha*V)
        
        prob_tweet = prob_tweet * p
        
    prob_final = prob_tweet * prob_cat('N')
    dicN[tweet] = prob_final

# %%
prob_P = 1
prob_tweet = 1
dicP = {}
for tweet in excel_treino['Teste']:
    tweet = cleanup(tweet)
    pal_tweet = tweet.split()
    for palavra_teste in pal_tweet:
        c = 0
        if palavra_teste in Fqp:
            c = Fqp[palavra_teste]
        p = (c + alpha)/(pP + alpha * V)
        prob_tweet = prob_tweet * p

        
    prob_final = prob_tweet * prob_cat('P')
    dicP[tweet] = prob_final

dicP
# Out:
# 3.895531824996729e-05
# 3.995417256406901e-06
# 5.993125884610352e-06
# 9.988543141017252e-07
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.298510608332243e-05
# 9.988543141017252e-07
# 1.498281471152588e-05
# 9.988543141017252e-07
# 1.1986251769220704e-05
# 3.895531824996729e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 6.29278217884087e-05
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 7.990834512813802e-06
# 7.990834512813802e-06
# 1.9977086282034504e-06
# 7.990834512813802e-06
# 7.990834512813802e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 5.993125884610352e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 7.990834512813802e-06
# 6.991980198712077e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017254e-06
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 4.994271570508627e-06
# 2.097594059613623e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.996562942305176e-06
# 1.9977086282034504e-06
# 1.1986251769220704e-05
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 3.995417256406901e-06
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 3.995417256406901e-06
# 9.988543141017252e-07
# 1.3983960397424155e-05
# 1.9977086282034504e-06
# 6.29278217884087e-05
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 1.0987397455118979e-05
# 6.991980198712077e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 3.895531824996729e-05
# 4.994271570508627e-06
# 2.996562942305176e-05
# 6.29278217884087e-05
# 1.9977086282034504e-06
# 1.1986251769220704e-05
# 1.3983960397424155e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 3.895531824996729e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 3.895531824996729e-05
# 9.988543141017252e-07
# 1.3983960397424155e-05
# 2.097594059613623e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 4.994271570508627e-06
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 2.996562942305176e-06
# 2.996562942305176e-05
# 3.995417256406901e-06
# 9.988543141017252e-07
# 4.994271570508627e-06
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 8.989688826915529e-06
# 9.988543141017252e-07
# 4.994271570508627e-06
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.1986251769220704e-05
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.996562942305176e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 5.993125884610352e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 9.988543141017254e-06
# 4.994271570508627e-06
# 2.996562942305176e-05
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017254e-06
# 7.990834512813802e-06
# 2.996562942305176e-06
# 3.995417256406901e-06
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 8.989688826915529e-06
# 2.996562942305176e-05
# 9.988543141017254e-06
# 7.990834512813802e-06
# 2.996562942305176e-06
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.3983960397424155e-05
# 1.498281471152588e-05
# 9.988543141017252e-07
# 6.29278217884087e-05
# 1.0987397455118979e-05
# 2.097594059613623e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 3.995417256406901e-06
# 9.988543141
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.1986251769220704e-05
# 4.994271570508627e-06
# 3.995417256406901e-06
# 1.9977086282034504e-06
# 1.9977086282034504e-06
# 6.991980198712077e-06
# 9.988543141017252e-07
# 5.993125884610352e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 5.993125884610352e-06
# 9.988543141017252e-07
# 8.989688826915529e-06
# 4.994271570508627e-06
# 1.498281471152588e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.097594059613623e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.996562942305176e-06
# 9.988543141017252e-07
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 4.994271570508627e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.996562942305176e-06
# 3.995417256406901e-06
# 9.988543141017252e-07
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 4.994271570508627e-06
# 6.991980198712077e-06
# 2.996562942305176e-06
# 6.29278217884087e-05
# 9.988543141017252e-07
# 7.990834512813802e-06
# 5.993125884610352e-06
# 1.9977086282034504e-06
# 2.996562942305176e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 7.990834512813802e-06
# 7.990834512813802e-06
# 4.994271570508627e-06
# 7.990834512813802e-06
# 7.990834512813802e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 5.993125884610352e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 7.990834512813802e-06
# 6.991980198712077e-06
# 9.988543141017252e-07
# 6.991980198712077e-06
# 1.9977086282034504e-06
# 9.988543141017254e-06
# 1.3983960397424155e-05
# 1.9977086282034504e-06
# 6.29278217884087e-05
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 1.9977086282034504e-06
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 2.996562942305176e-06
# 9.988543141017252e-07
# 8.989688826915529e-06
# 2.097594059613623e-05
# 1.0987397455118979e-05
# 7.990834512813802e-06
# 1.3983960397424155e-05
# 2.996562942305176e-06
# 3.895531824996729e-05
# 1.9977086282034504e-06
# 1.3983960397424155e-05
# 9.988543141017252e-07
# 6.991980198712077e-06
# 9.988543141017252e-07
# 6.892094767301905e-05
# 7.291636492942594e-05
# 6.892094767301905e-05
# 9.988543141017252e-07
# 1.298510608332243e-05
# 5.993125884610352e-06
# 9.988543141017252e-07
# 2.996562942305176e-06
# 2.996562942305176e-05
# 3.995417256406901e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 9.988543141017252e-07
# 2.996562942305176e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 8.989688826915529e-06
# 9.988543141017252e-07
# 9.988543141017252e-07
# 1.9977086282034504e-06
# 9.988543141017252e-07
# 6.892094767301905e-05
# 7.291636492942594e-05
# ...
#  'acho q sou a única que chora pra krl quando assiste 13 reasons why': 0.0,
#  'terminei 13 reasons why já faz um tempo  é uma série marcante': 0.0,
#  'terminei a segunda temporada de elite e  eu já desconfiava que tudo isso ia acontecer desde o primeiro episódio  a… https //t co/jwdpygbh3c': 0.0,
#  '@mdslea @leamvchle mas semana passada teve o rolo lá da atriz de 13 reasons why que chegou a excluir suas redes soc… https //t co/78tds7zc3z': 0.0,
#  'depois de sofrer pra terminar esta bomba de temporada de 13 reasons why eu finalmente vou voltar a ver minha olivia pope': 0.0,
#  'mano essa série 13 reasons why mexeu cmg 😭😭😭': 0.0,
#  '4ª temporada de 13 reasons why   o que vai acontecer  a última fita da h    https //t co/msypp6mlub via @youtube': 0.0,
#  'descreveu a terceira temporada de 13 reasons why todinha https //t co/aepxh0xbrs': 0.0,
#  'se esse samuel morrer vou fazer uma festinha aqui em cada  mlk chato do caralho  igual aquela ani de 13 reasons why… https //t co/goihpke9p1': 0.0,
#  'nunca vi la casa de papel  nem 13 reasons why  nem greys anatomy  nem elite  nem pra todos os garotos que ja amei … https //t co/237gemxmln': 0.0,
#  'https //t co/czlgnxc36s (o inacreditável cinismo de 13 reasons why) a pior série da netflix': 0.0,
#  'que final bosta da 3° temporada de 13 reasons why  só assistir pq eu sou apaixonado pelo justin  achei que o fdp do… https //t co/4y92krzffq': 0.0,
#  '@manu_newhouse eu não cheguei a assistir aquela série lá 13 reasons why  mas ao meu ver é basicamente um "passo a p… https //t co/tzqjrdyjge': 0.0,
#  'aí você entra em um quarto  e pá  é surpreendida com um spoiler da 3º temporada de 13 reasons why  😑\n\n#habbo https //t co/ypje484bgf': 0.0,
#  'quem não gosta de 13 reasons why não entende nada  nadinha sobre a vida     \n\nsérie expressiva da porra  \n\nconsegue… https //t co/luz2qmpsic': 0.0,
#  '  sobre séries  \n\n1  the vampire diaries \n2  pretty little liars\n3  the punisher\n4  13 reasons why (tentei mais não… https //t co/bb5s3icn4j': 0.0,
#  'vou tentar dá mas uma chance pra 3 temporada de 13 reasons why ': 0.0,
#  'rt @vieiraagabriela  a terceira temporada de 13 reasons why estreou faz umas duas semanas e eu não consigo assistir um episódio sem ficar c…': 0.0,
#  'ai meu deus pode me julgar como o garoto que esta vendo a terceira temporada da série tóxica 13 reasons why': 0.0,
#  'sensata é a pessoa que ergueu a placa pedindo o fim de 13 reasons why': 0.0,
#  'não vejo 13 reasons why como uma série q incentiva essas coisas  ela servem pra alertar q isso é real  mto sério mesmo': 0.0,
#  'achei essa segunda temporada de elite bem meio 13 reasons why': 0.0,
#  '  sobre séries  \n\n1  ahs\n2  titans\n3  ahs\n4  13 reasons why\n5  puts    sla\n6  2 broke girls\n7  devo ter chorado em… https //t co/kkbwnsurwr': 0.0,
#  'lançou a 2° tmp de elite  e eu nem terminei de assistir a 3° de 13 reasons why   e mês que vem vai lançar a 4°tmp d… https //t co/fyrpltdbnh': 0.0,
#  'preciso atualizar elite e 13 reasons why  porém to muito sem tempoooo': 0.0,
#  'começando a terceita temporada de 13 reasons why agora  não me julguem  to passando mal e já tentei estudar': 0.0,
#  'acho que não é uma boa idéia assistir 13 reasons why': 0.0,
#  'elite tem uma história que te prende rápido  13 reasons why    meu pai do céu  da sempre vontade de dormir   ': 0.0,
#  "atribuí nota 8 ao episódio 3x5   nobody's clean de 13 reasons why https //t co/m8zlbho5fz #bancodeseries": 0.0,
#  'então glr  lá vai\n\neu nunca assisti \n\na lagoa azul\nnenhum filme de harry potter\nas crônicas de nárnia\n13 reasons why\na hora do pesadelo': 0.0,
#  'manoooooo  não ta dandooo     \ntenho que assistir elite  13 reasons why  grey’s anatomy e aindaaaa tem a dona do pe… https //t co/4sa2ckhtwi': 0.0,
#  'e eu que vim pra cá ver spoilers de 13 reasons why e tô indignada de ter visto os spoilers': 0.0,
#  'pq enfiaram essa menina chata pra ficar narrando em 13 reasons why ': 0.0,
#  'caralho os últimos episódios de 13 reasons why é perturbador': 0.0,
#  'que dia pouco produtivo mas finalmente acabei 13 reasons why': 0.0,
#  "tô ligada que ceis não perdem tempo com besteira  mas vou avisar  fujam da 3a temp  de '13 reasons why'  aliás  a p… https //t co/1tubbhwobt": 0.0,
#  'acabei de ver o último ep da temp 2 de 13 reasons why    vou ficar perturbada pro resto da minha vida n to brincando': 0.0,
#  'o pior erro da 3ª temp  de 13 reasons why foi tentar mudar a imagem de bryce  me poupe  o cara estupra mais de 10 m… https //t co/tgemqibdqt': 0.0,
#  'a 2 temporada de elite continua a imitar 13 reasons why   \nvou deixar de ver': 0.0,
#  'o final da 3 temp de 13 reasons why tá foda demais': 0.0,
#  'skol e 13 reasons why melhor sextou pra hoje': 0.0,
#  'elite ja ta no ar e eu ainda nao terminei 13 reasons why as telefonistas vis e vis': 0.0,
#  'passar a sexta olhando 13 reasons why  que horror': 0.0,
#  'rt @queridojeito  “a grama do vizinho é sempre mais verde ” \n— 13 reasons why\nhttps //t co/ixujaakyhy https //t co/790oilylkh': 0.0,
#  'pq q eu ainda invento de ver 13 reasons why': 0.0,
#  'eu to com um ódio dessa enxerida da ani em 13 reasons why \nchegou agora e fica se metendo em tudo \nmenina chata da porra  meu deeeeeus': 0.0,
#  'vei essa temporada de elite tá a mesma coisa de 13 reasons why': 0.0,
#  'enquanto não tenho um pingo de coragem para continuar assistindo 13 reasons why ': 0.0,
#  'rt @thwwiww  19  13 reasons why é o primeiro trabalho principal da katherine  antes da série  ela só participou de 2 curtas metragens como…': 0.0,
#  'de todas as temporadas de 13 reasons why a que eu mais chorei foi essa 3ª pqp q série': 0.0,
#  '  sobre séries  \n\n1  pretty little liars sdds quando era boa\n2  eu não consigo escolher\n3  friends/himym\n4  got\n5 … https //t co/ukgaopizab': 0.0,
#  'ai vem a 3 temporada com a morte do polo aaaaaaaa é  isso mesmo chernoflix elite é a versão latina de 13 reasons wh… https //t co/hh02nk9kjb': 0.0,
#  'rt @fe90up  @mussumalive euphoria não se compara nem com elite e nem com 13 reasons why  aliás  em termos técnicos tá a anos luz dessas dua…': 0.0,
#  'to quase acabando a 3° terceira de 13 reasons why': 0.0,
#  'só 13 reasons why pq puta merda nékkk': 0.0,
#  'rt @queridojeito  “a sensação é um nada  como um vazio  sem fim  um grande nada ” \n— 13 reasons why\nhttps //t co/ixujaakyhy https //t co/el…': 0.0,
#  'mano a cada episódio de 13 reasons why é um tiro  tô no último episódio e tô doida p saber quem é o assassino': 0.0,
#  'rt @brunotarioo  passando uma raiva com 13 reasons why que puta que pariu  se a ani estiver na 4 temporada eu juro que não vou mais assistir': 0.0,
#  'lançou elite e eu nem terminei 13 reasons why aaaaa': 0.0,
#  'poxa devin druid como vc se sente carregando toda a temporada de 13 reasons why nas costas ': 0.0,
#  'ai que final meio bosta de elite  vão ficar enrolando até a 10 temporada     (o mal de 13 reasons why meu pai)': 0.0,
#  'só queria acabar 13 reasons why logo': 0.0,
#  '@caio_a0 amigo  vc ve 13 reasons why  nao pode falar nada ok': 0.0,
#  'mano eu amo 13 reasons why vsf\nmas eu achei meio injusto o final ': 0.0,
#  '13 reasons why é uma puta série boa e digo isso com convicção': 0.0,
#  'acabei de assistir ao episódio s03e10 de 13 reasons why  #tvtime https //t co/y3ddtcoe7z https //t co/evmgwtt7si': 0.0,
#  'acabei de assistir ao episódio s03e01 de 13 reasons why  #tvtime https //t co/pecy8tl78q https //t co/s2ojccgwol': 0.0,
#  'cara  é impressionante como a terceira temporada de 13 reasons why está boa  o tyler contando o que houve com ele p… https //t co/ked04svqs3': 0.0,
#  'mas um seriado que não me atrai    \nfoi um tormento para terminar a primeira temporada de elite      não assisti go… https //t co/tpwtvdxohr': 0.0,
#  '@uenaath comecei a assistir grey’s já kkkk agora só falta elite e 13 reasons why': 0.0,
#  'alguém assistiu a terceira temporada de 13 reasons why  se assistiu  sabe me dizer se tá boa ou tá uma merda  pq a… https //t co/2pzsnmdxm3': 0.0,
#  'eu sei q 13 reasons why é uma serie bem fudida mas a mensagem ainda ta la gnt  n foi executado da melhor maneira mas ta la': 0.0,
#  'eu to doida p começar a segunda temporada de elite mas quero terminar 13 reasons why': 0.0,
#  '@carolinatrento_ não sou dessassss \n\njá terminei e comecei a 3ª de 13 reasons why': 0.0,
#  'nem acredito que to assistindo a tóxica 13 reasons why de curiosidade': 0.0,
#  'é sério que tem 3ª temp de 13 reasons why  eu me perguntou whyyy ': 0.0,
#  'legal essa versão fofa e humana do bryce walker q fizeram em 13 reasons why\nnota zero    ': 0.0,
#  '@brummm29 tu me indicou a série (13 reasons why) e eu estou amando  skksksk  não é tão péssima assim': 0.0,
#  'gente não sei se eu assisto 13 reasons why  sei lá  a série devia ter acabado na 2ª temp  to com impressão que não… https //t co/tqjsy45mup': 0.0,
#  'gent assistam 13rw  essa série é a mais pft q existe  ela ensina vc a reconhecer as pessoas  a aprender em quem rea… https //t co/ipby99z1ab': 0.0,
#  '13 reasons why está bué podre e ainda só vou no primeiro episódio': 0.0,
#  "@brbararoberta11 grey's anatomi\n13 reasons why\nelite \nlá casa de papel\nriverdale \na maldição da residência hill \nlúcifer": 0.0,
#  'muito chata a 3 temporada de 13 reasons why': 0.0,
#  'rt @ggukkietalent  3° temporada de 13 reasons why e 2° temporada de elite     qual vejo primeiro     acho que vai ser elite msm': 0.0,
#  '@lubinhu é eu acho q vc entendeu errado  eu falei q odiei as duas  a segunda temporada de elite e a terceira temporada de 13 reasons why ': 0.0,
#  'que raiva daquele recado que tem no início de 13 reasons why "se você estiver passando por algo parecido não assist… https //t co/qemeudou7h': 0.0,
#  'só pra atualizar 13 reasons why é a melhor série pra sempre  chorando litros com esse ep final  socorro ': 0.0,
#  'torando um prato de macarrão com calabresa e bacon e assistindo 13 reasons why  serasi que termino essa 3° temp hoje  ': 0.0,
#  'se vcs for assistir a 3 temp de 13 reasons why vão ficar meio perturbados né  mas vão parar pra pensar e ver que qu… https //t co/onsynkvjqh': 0.0,
#  '@maferreiraf vou silenciar enquanto é tempo então kkkkkkkkkkkkkkkkk estou no 6° de 13 reasons why devo acabar hoje… https //t co/jrlxaicatd': 0.0,
#  'silêncio um jovem está assistindo sua série  s03e10 of 13 reasons why  #13reasonswhy  #tvtime… https //t co/vnmdxvjman': 0.0,
#  'caralho 13 reasons why foi massacrada por elite https //t co/cmpniew5nt': 0.0,
#  '13 reasons why já foi melhor  3 temporada bosta 👍🙄': 0.0,
#  'gente eu to me sentindo muito mal  por ter chorado pela morte do bryce de 13 reasons why': 0.0,
#  "ok  eu admito talvez eu tenha voltado a assistir 13 reasons why  '(": 0.0,
#  'gostei da 2 temp de elite mas mano pra mim tá parecendo com 13 reasons why já  morte dessa menina vai se arrastar até onde der': 0.0,
#  'rt @matheusjucinsky  ➡️ clica aqui  https //t co/f70khzcy1g\n\ndepois de descobrirmos quem é o verdadeiro assassino do bryce walker    o que…': 0.0,
#  '  sobre séries  \n\n1  the vampire diaries\n2  sherlock\n3  sherlock\n4  friends\n5  13 reasons why\n6  brooklyn 99\n7  nen… https //t co/c6frlf31ta': 0.0,
#  'baixando os eps de 13 reasons why p ver dps': 0.0,
#  '13 reasons why tá ficando cada vez melhor  não da vontade de parar de ver': 0.0,
#  'fui começar a assistir a 3ª temp de 13 reasons why  mas dps de ver o resumo da 2ª não sei se tenho psicológico pra ver': 0.0,
#  'rt @queridojeito  vem ver as frases da série 13 reasons why\nacesse e confira  \nhttps //t co/ixujaakyhy': 0.0,
#  'rt @juandesouza_de  13 reasons why  terceira temporada tá foda demais': 0.0,
#  'atribuí nota 9 ao episódio 3x4   angry  young and man de 13 reasons why https //t co/weismdcu9p #bancodeseries': 0.0,
#  'acabei de assistir ao episódio s03e12 de 13 reasons why  #13reasonswhy  #tvtime https //t co/uma5z6hckl https //t co/muminbyldn': 0.0,
#  'marilia se vc esta bolada com o final de 13 reasons why  é pq vc n viu o de elite  é arrancar os cabelos da cabeça': 0.0,
#  'acabei de assistir ao episódio s03e11 de 13 reasons why  #13reasonswhy  #tvtime https //t co/lassinhqcf https //t co/xhut7uqkly': 0.0,
#  'tocha querendo comparar "13 reasons why" com naruto kkkkkkkkkkkkkkkk nunca vi roupa dessa seriezinha medíocre p ven… https //t co/8lry3pgnd4': 0.0,
#  'agora vamos falar de 13 reasons why\n\nque ranço dessa ani  garota insuportável  sonsa e mentirosa  só estragou ainda mais a série': 0.0,
#  "atribuí nota 10 ao episódio 3x1   yeah  i'm the new girl de 13 reasons why https //t co/7sreqrlfqh #bancodeseries": 0.0,
#  'no os está recordando la segunda temporada de elite a 13 reasons why ': 0.0,
#  'gostei dum negócio que vi na série 13 reasons why \n\nolha vou te dizer uma das piores coisas que já fiz  transei com… https //t co/a2il53qwpc': 0.0,
#  'fav e mando 6 perguntas por dm \n\n1  m d g a\n2  d\n3  laranja\n4  13 reasons why\n5  l\n6  🤷\u200d♀️': 0.0,
#  '  sobre séries  \n\n1  glee\n2  american horror story\n3  chilling adventures of sabrina\n4  13 reasons why\n5  pll\n6  fr… https //t co/gbg4bxwtcf': 0.0,
#  'ta bom  talvez eu assista 13 reasons why só por causa do zack': 0.0,
#  'ep 13 da segunda temporada de 13 reasons why  meu peito está quentinho mds que lindu  (': 0.0,
#  'agora eis a questão \n  terminar de ver mindhunter \n  ver segunda temporada de elite\n  ver terceira temporada da tóxica 13 reasons why': 0.0,
#  'gostaram dessa temporada nova do 13 reasons why ': 0.0,
#  'finalmente terminei de assistir a terceira temporada de 13 reasons why  muitas caixas de surpresas  emoções  relaci… https //t co/lcpda9dx4k': 0.0,
#  'tô assistindo "13 reasons why" e estou tipo pasma com essa terceira temporada ': 0.0,
#  '@v_dorinato 13 reasons why é o motivo kkkkk': 0.0,
#  '  sobre séries  \n\n1  supernatural\n2  supernatural\n3  supernatural\n4  got\n5  13 reasons why\n6  (des)encanto\n7  stran… https //t co/llmzeytbqn': 0.0,
#  'atribuí nota 10 ao episódio 3x7   there are a number of problems with clay jensen de 13 reasons why https //t co/rztcu62foy #bancodeseries': 0.0,
#  'depois dessa apresentação vou colocar algumas séries em dia \njá tenho uma lista \nriverdale\n13 reasons why\nla casa papel \nvis a vis \nelite': 0.0,
#  'terminei elite e cheguei na conclusão de que virou 13 reasons why': 0.0,
#  'eu acabei de ver o episodio s03e01 de 13 reasons why  #13reasonswhy  #tvtime https //t co/yejxc7rrhs https //t co/dspssx1z8p': 0.0,
#  'elite  greys anatomy e 13 reasons why sabendo q vão roubar td meu tempo livre https //t co/i1mpkml2m0': 0.0,
#  "rt @citou13reasons  ''quando as pessoas estão em circunstâncias extremas podem agir fora do padrão  ás vezes com um final trágico ''\n— 13 r…": 0.0,
#  'rt @queridojeito  “algumas coisas não têm uma explicação simples ” \n— 13 reasons why\nhttps //t co/ixujaakyhy https //t co/rutnony5ex': 0.0,
#  'chorei muito com esse final de 13 reasons why 😭😭❤❤': 0.0,
#  'rt @stellalucenaa  terminei 13 reasons why e ainda não acredito que foi alex que matou o bryce': 0.0,
#  'vou assistir a temporada nova 13 reasons why  agr': 0.0,
#  'meu colega de trabalho me contou o final da terceira temporada de 13 reasons why  sabendo que eu quero assistir  nã… https //t co/3tenyyi0nz': 0.0,
#  'rt @psodre22  vou terminar 13 reasons why e começar a segunda temporada de elite': 0.0,
#  'rt @sofiacostaaa  não é só setembro que você tem que se preocupar com qm tem depressão  são todos os meses  todos os dias  vejo muita gente…': 0.0,
#  "rt @citou13reasons  ''a tristeza faz a gente agir de maneiras inesperadas ''\n— 13 reasons why": 0.0,
#  'mano  13 reasons why pode ter um conteúdo super pesado que serve como gatilho  porém eles sempre avisam e indicam q… https //t co/xuiir8r9io': 0.0,
#  'rt @oarcadiobr  temas importantes como suicídio  bullying e agressões sexuais são trabalhados em #13reasonswhy da maneira mais porca possív…': 0.0,
#  'a trilha sonora de 13 reasons why = tudo pra mim  minha razão pra viver 🥰': 0.0,
#  "rt @citou13reasons  ''violência gera violência  só que nem sempre parece a mesma ''\n— 13 reasons why": 0.0,
#  '  sobre séries  \n\n1  glee ( acho) \n2  no momento lúcifer \n3  modern family\n4  não sei \n5  13 reasons why \n6  b99 \n7… https //t co/mvdoavyi9a': 0.0}

# %%
# prob_O = 1
# prob_tweet = 1
# dicO = {}
# for tweet in excel_treino['Teste']:
#     tweet = cleanup(tweet)
#     pal_tweet = tweet.split()
#     for palavra_teste in pal_tweet:
#         c = 0
#         if palavra_teste in Fqo:
#             c = Fqo[palavra_teste]
#         p = (c + alpha)/(pO + alpha*V)
#     prob_tweet = prob_tweet * prob_cat('O')
#     dicO[tweet] = prob_tweet

# %%
prob_O = 1
prob_tweet = 1
dicO = {}
for tweet in excel_treino['Teste']:
    tweet = cleanup(tweet)
    pal_tweet = tweet.split()
    for palavra_teste in pal_tweet:
        c = 0
        if palavra_teste in Fqo:
            c = Fqo[palavra_teste]
        p = (c + alpha)/(pO + alpha*V)
        
        prob_tweet = prob_tweet *p
        
    prob_final = prob_tweet * prob_cat('O')
    dicO[tweet] = prob_final

# %%
print(dicN['a coisa mais idiota de 13 reasons why foi colocar o zac e a cheryl nas fitas  botaram eles num nível de fdp igual aos outros desnecessário'])
# Out:
# 8.278663222515704e-142

# %%
print(dicO['a coisa mais idiota de 13 reasons why foi colocar o zac e a cheryl nas fitas  botaram eles num nível de fdp igual aos outros desnecessário'])
# Out:
# 2.0127996300538467e-138

# %%
print(dicR['a coisa mais idiota de 13 reasons why foi colocar o zac e a cheryl nas fitas  botaram eles num nível de fdp igual aos outros desnecessário'])
# Out:
# 1.3387349140981414e-144

# %%
print(dicP['a coisa mais idiota de 13 reasons why foi colocar o zac e a cheryl nas fitas  botaram eles num nível de fdp igual aos outros desnecessário'])
# Out:
# 5.191986819776369e-146

# %%
tweets_classificados = []
tweet = 0

for tweet in excel_treino['Teste']:
    tweet = cleanup(tweet)
    pal_tweet = tweet.split()
    maior = dicN[tweet]
    if maior < dicP[tweet]:
        maior = dicP[tweet]
    elif maior < dicO[tweet]:
        maior = dicO[tweet]
    elif maior < dicR[tweet]:
        maior = dicR[tweet]
        
    if maior == dicR[tweet]:    
        tweets_classificados.append('R')
    elif maior == dicN[tweet]:    
        tweets_classificados.append('N')
    elif maior == dicP[tweet]:    
        tweets_classificados.append('P')
    elif maior == dicO[tweet]:
        tweets_classificados.append('O')

tweets_classificados
# Out:
# ['O',
#  'P',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R']

# %%
excel_treino
# Out:
#                                                  Teste Clas_manual Previsto
# 0    a coisa mais idiota de 13 reasons why foi colo...           N        O
# 1    atribuí nota 8 ao episódio 3x1 - yeah. i'm the...           O        O
# 2    rt @citou13reasons: ''quando você julga uma pe...           O        O
# 3    terminei 13 reasons why também, meu hobbie é c...           R        O
# 4    rt @wivisampaio: saiu a nova temporada de elit...           O        O
# 5    a verdade é que 13 reasons why deveria ter ter...           N        O
# 6    vou adicionar um comentário aqui. não adianta ...           O        O
# 7    @fernaandabb se você curte 13 reasons why, tal...           O        O
# 8    essa última temporada de 13 reasons  why tá fo...           P        O
# 9    13 reasons why, terceira temporada tá foda demais           P        O
# 10   13 reasons why é o tipo de série que te faz ac...           R        O
# 11   @tainaammys ex do sam smith daquela série 13 r...           O        O
# 12           @lucasranngel tá parecendo 13 reasons why           O        O
# 13   alguém me conta a 3 temp de 13 reasons why, to...           O        O
# 14   terminei a terceira temporada de 13 reasons wh...           P        O
# 15   a trilha sonora da terceira temporada de 13 re...           P        O
# 16   sem psicologico pra terminar de assistir 13 re...           R        O
# 17   • sobre séries •\n\n1.  icarly\n2. once upon a...           O        O
# 18   rt @meandretta1: nao sei se começo a assistir ...           O        O
# 19   13 reasons why se resolveria em um episódio se...           R        O
# 20   tô com um medo tão grande de continuar assisti...           R        O
# 21   @trilogyend ??? existe riverdale e 13 reasons ...           O        O
# 22   rt @liviagrable: to atrasada com as minhas sér...           O        O
# 23   • sobre séries •\n\n1. vikings\n2. lá casa de ...           O        O
# 24   elite é tipo uma versão 10x melhor de 13 reaso...           N        O
# 25   acabei de assistir ao episódio s03e13 de 13 re...           O        O
# 26   rt @queridojeito: “há pessoas que se machucam ...           O        O
# 27   acabei de assistir ao episódio s03e05 de 13 re...           O        O
# 28   pessoas que gostam de elite não tem moral nenh...           O        O
# 29   assistindo a 3temp de 13 reasons why com a for...           N        O
# ..                                                 ...         ...      ...
# 368  gostei dum negócio que vi na série 13 reasons ...           O        O
# 369  fav e mando 6 perguntas por dm \n\n1- m,d,g,a\...           O        O
# 370  • sobre séries •\n\n1. glee\n2. american horro...           O        O
# 371  ta bom, talvez eu assista 13 reasons why só po...           O        O
# 372  ep 13 da segunda temporada de 13 reasons why, ...           P        O
# 373  agora eis a questão \n- terminar de ver mindhu...           O        O
# 374   gostaram dessa temporada nova do 13 reasons why?           O        O
# 375  finalmente terminei de assistir a terceira tem...           R        O
# 376  tô assistindo "13 reasons why" e estou tipo pa...           R        O
# 377        @v_dorinato 13 reasons why é o motivo kkkkk           O        O
# 378  • sobre séries •\n\n1. supernatural\n2. supern...           O        O
# 379  atribuí nota 10 ao episódio 3x7 - there are a ...           P        O
# 380  depois dessa apresentação vou colocar algumas ...           O        O
# 381  terminei elite e cheguei na conclusão de que v...           O        O
# 382  eu acabei de ver o episodio s03e01 de 13 reaso...           O        O
# 383  elite, greys anatomy e 13 reasons why sabendo ...           O        O
# 384  rt @citou13reasons: ''quando as pessoas estão ...           O        O
# 385  rt @queridojeito: “algumas coisas não têm uma ...           O        O
# 386  chorei muito com esse final de 13 reasons why ...           R        O
# 387  rt @stellalucenaa: terminei 13 reasons why e a...           O        O
# 388  vou assistir a temporada nova 13 reasons why, agr           O        O
# 389  meu colega de trabalho me contou o final da te...           O        O
# 390  rt @psodre22: vou terminar 13 reasons why e co...           O        O
# 391  rt @sofiacostaaa: não é só setembro que você t...           O        O
# 392  rt @citou13reasons: ''a tristeza faz a gente a...           O        O
# 393  mano, 13 reasons why pode ter um conteúdo supe...           O        O
# 394  rt @oarcadiobr: temas importantes como suicídi...           N        O
# 395  a trilha sonora de 13 reasons why = tudo pra m...           P        O
# 396  rt @citou13reasons: ''violência gera violência...           O        O
# 397  • sobre séries •\n\n1. glee ( acho) \n2. no mo...           O        O
#
# [398 rows x 3 columns]

# %% [markdown]
# #### Acurácia:

# %%
P = 0
falso_P = 0
O = 0
falso_O = 0
R = 0
falso_R = 0
N = 0
falso_N = 0


total = len(excel_treino["Teste"])

# for [e,i] in zip(excel_treino["Teste"], excel_treino["Previsto"]):
#     if e == 1:
#         if i == 1:
#             P += 1
#         else: 
#             falso_P += 1
#     if e == 2:            
#         if i == 2:
#             N +=1
#         else:
#             falso_N +=1
#     if e == 2:            
#         if i == 2:
#             O +=1
#         else:
#             falso_O +=1
#     if e == 2:            
#         if i == 2:
#             R +=1
#         else:
#             falso_R +=1

i = 0
while i < len(excel_treino['Clas_manual']):
    if excel_treino['Clas_manual'][i] == 'N':
        if excel_treino['Previsto'][i] == 'N':
            N += 1
        else:
            falso_N += 1
        
    if excel_treino['Clas_manual'][i] == 'P':
        if excel_treino['Previsto'][i] == 'P':
            P += 1
        else:
            falso_P += 1
            
    if excel_treino['Clas_manual'][i] == 'O':
        if excel_treino['Previsto'][i] == 'O':
            O += 1
        else:
            falso_O += 1
    
    if excel_treino['Clas_manual'][i] == 'R':
        if excel_treino['Previsto'][i] == 'R':
            R += 1
        else:
            falso_R += 1
    i += 1

# %%
print("Positivos Verdadeiros: ", round((P/total)*100,2), "%")
print("Positivos Falsos: ", round((falso_P/total)*100, 2), "%")
print("Negativos Verdadeiros: ", round((N/total)*100,2), "%")
print("Negativos Falsos: ", round((falso_N/total)*100, 2), "%")
print("Neutros Verdadeiros: ", round((O/total)*100,2), "%")
print("Neutros Falsos: ", round((falso_O/total)*100, 2), "%")
print("Reações Verdadeiros: ", round((R/total)*100,2), "%")
print("Reações Falsos: ", round((falso_R/total)*100, 2), "%")
print("_"*35)

print("Acertos: ", round(((P/total)+(N/total)+(O/total)+(R/total))*100,2), "%")
print("Erros: ", round(((falso_P/total)+(falso_N/total)+(falso_R/total)+(falso_O/total))*100,2), "%")
# Out:
# Positivos Verdadeiros:  0.0 %
# Positivos Falsos:  10.55 %
# Negativos Verdadeiros:  0.0 %
# Negativos Falsos:  18.84 %
# Neutros Verdadeiros:  52.51 %
# Neutros Falsos:  0.0 %
# Reações Verdadeiros:  0.0 %
# Reações Falsos:  18.09 %
# ___________________________________
# Acertos:  52.51 %
# Erros:  47.49 %

# %% [markdown]
# ### **DASHBOARD**

# %%
#print(len(tweets_classificados))

# %%
# from time import sleep
# import pandas as pd

# for e in range(3):
#     !jupyter nbconvert --to notebook --execute Projeto2_layout.ipynb
#     dashboard = pd.readExcel("13 Reasons Why novo.xlsx")
#     print(f"dashoard: {dashoard}")
#     sleep(5)


# excel_treino.to_excel('fill_auto1.xlsx')

# %%
from time import sleep
while True:
    #getting new tweets
    #Cria um objeto para a captura
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

    #Inicia a captura, para mais detalhes: ver a documentação do tweepy
    i = 1
    msgs = []
    for msg in tweepy.Cursor(api.search, q=produto, lang=lang).items():    
        msgs.append(msg.text.lower())
        i += 1
        if i > n:
            break

    #Embaralhando as mensagens para reduzir um possível viés
    lista = []
    shuffle(msgs)

    #Usando o set() para tirar os retweets
    listaset = set(msgs)

    #Adicionando o resultado do set() a uma lista para evitar o erro TypeError: 'set' object is not subscriptable
    for value in listaset:
        lista.append(value)
    
    #criando dataframe com novos tweets
    df_teste = pd.DataFrame({'Teste' : pd.Series(lista)})
    
    #classifie new tweets
    tweets_classificados = []

    for tweet in excel_treino['Teste']:
        tweet = cleanup(tweet)
        pal_tweet = tweet.split()
        maior = dicN[tweet]
        if maior < dicP[tweet]:
            maior = dicP
            tweets_classificados.append('P')
        elif maior < dicO[tweet]:
            maior = dicO
            tweets_classificados.append('O') 
        elif maior < dicR[tweet]:
            maior = dicR
            tweets_classificados.append('R')
        else:
            tweets_classificados.append('N')
            
    df_teste['Categorias'] = tweets_classificados
    
    #mostrar na dashboard:
    

    sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-573da29bb934> in <module>
#       3     #getting new tweets
#       4     #Cria um objeto para a captura
# ----> 5     api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
#       6
#       7     #Inicia a captura, para mais detalhes: ver a documentação do tweepy
#
# NameError: name 'auth' is not defined

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que periodicamente realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# ___
# ### Por que não se pode utilizar o próprio classificador para gerar mais amostras de treinamento?

# %% [markdown]
#     Ao se utilizar o próprio classificador para gerar mais amostras de treinamento, o classificador acaba ficando
#     'viciado', ou seja, acaba-se por prejudicar os resultados obtidos, e eles acabam não tendo uma qualidade boa.
#     Seria o contrário de puxar mais tweets, que melhora a qualidade dos dados e dos resultados, por ter um espaço
#     amostral muito maior.

# %% [markdown]
# ### Outras limpezas e tranformações:
# ___
#     - Trocar vírguças por espaços
#     - Remover URLs

# %% [markdown]
# ### Outros cenários de Naive Bayes fora do contexto do projeto
# ___

# %% [markdown]
#     - Previsão de Chuva
#     - Filtros de e-mail (Spam)

# %% [markdown]
# # Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
#
# https://towardsdatascience.com/naive-bayes-classifier-81d512f50a7c
#
# https://www.geeksforgeeks.org/naive-bayes-classifiers/
#
# https://www.analyticsvidhya.com/blog/2017/09/naive-bayes-explained/

# %%
# probP = 0
# probN = 0
# probR = 0
# probO = 0
# i = 0
# dic_catR = {}
# dic_catP = {}
# dic_catN = {}
# dic_catO = {}


# #Para cada tweet na planilha:
# for tweet in excel_treino['Teste']:
#     tweet = cleanup(tweet.lower())
#     pal_tweet = tweet.split()
#     #Para cada palavra de cada tweet:
#     for palavra in pal_tweet:
#         um = True
#         for palavra1, frequencia in Fqr.items():
#             if um == True:
#                 #Seta a frquencia inicial de cada palavra para 1
#                 dic_catR[tweet] = 1
#             um = False
#             # probabilidade total são todas as probabilidades das palavras multiplicadas pela probabilidade de certa categoria
#             dic_catR[tweet] = dic_catR[tweet] *  prob_cat('R') * frequencia
                              
#         for palavra1, frequencia in Fqn.items():
#             if um == True:
#                 dic_catN[tweet] = 1
#             um = False
#             dic_catN[tweet] = dic_catN[tweet] *  prob_cat('N') * frequencia
            
#         for palavra1, frequencia in Fqp.items():
#             if um == True:
#                 dic_catP[tweet] = 1
#             um = False
#             dic_catP[tweet] = dic_catP[tweet] *  prob_cat('P') * frequencia

#         for palavra1, frequencia in Fqo.items():
#             if um == True:
#                 dic_catP[tweet] = 1
#             um = False
#             dic_catO[tweet] = dic_catP[tweet] *  prob_cat('O') * frequencia     

#         #Não precisa dividir pela probabilidade do tweet pois cancelaria.
    
# # fazer contador pra ver qual é a maior probabilidade, e adicionar em uma nova coluna do dataframe
# #  DataFrame.insert(2, 'Predição', [lista com letra de cada linha], True)
